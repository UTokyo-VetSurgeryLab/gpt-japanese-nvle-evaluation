# %%
#import pdfplumber

from src.services.converter import (
    #answer_pdf_converter_to_excel,
    #question_pdf_converter_to_excel,
    #extract_questions_to_excel,
    question_pdf_converter_to_excel_test,
)



path = "../problems/75th/essential"
#output_path = "../problems/74th/academic_d/questions_test2.xlsx"

question_pdf_converter_to_excel_test(path, is_test=True)
#extract_questions_to_excel(pdf_path, output_path)
# Out:
# があった。行政機関の動物愛護業務に携わる獣医師が行う飼い主への対応として
# 適当でないのはどれか。
# 〰〰〰〰〰
# question_texts:['隣家で多数の猫を屋外飼養しており、毎年子猫が生まれて困っているとの相談', 'があった。行政機関の動物愛護業務に携わる獣医師が行う飼い主への対応として', '適当でないのはどれか。']
# してよく説明することをいう。
# めではない。
# とである。
# 望んだとしても獣医師は決して動物の命を奪ってはいけない。
# question_texts:['インフォームドコンセントに関する記述として最も適切なのはどれか。']
# 送に関する記述として正しいのはどれか。
# question_texts:['動物実験における3R原則の組合せとして正しいのはどれか。']
# question_texts:['ペットロスに関する記述として最も適切なのはどれか。']
# 述として誤っているのはどれか。
# 〰〰〰〰〰
# 政府間機関はどれか。
# question_texts:['動物衛生の向上を目的として設立された、重要感染症防疫や動物福祉に関わる', '政府間機関はどれか。']
# 〰〰〰
# question_texts:['「と畜場法」で定める獣畜でないのはどれか。']
# 〰〰〰
# 法）」に関する記述として最も適切なのはどれか。
# question_texts:['「医薬品、医療機器等の品質、有効性及び安全性の確保等に関する法律（薬機', '法）」に関する記述として最も適切なのはどれか。']
# 〰〰〰〰〰
# な設備に貯蔵する。
# question_texts:['麻薬の使用と保管に関する記述として誤っているのはどれか。']
# いて獣医師が届け出る義務があるサルの感染症はどれか。
# 規定される特定外来生物に該当するのはどれか。
# question_texts:['「特定外来生物による生態系等に係る被害の防止に関する法律（外来生物法）」に', '規定される特定外来生物に該当するのはどれか。']
# 〰〰〰〰〰
# か。
# question_texts:['「家畜保健衛生所法」に定める家畜保健衛生所の業務として誤っているのはどれ', 'か。']
# ...
