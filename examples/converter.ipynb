# %%
#import pdfplumber

from services.converter import (
    #answer_pdf_converter_to_excel,
    question_pdf_converter_to_excel,
    #extract_questions_to_excel,
)



pdf_path = "./problems/74th/essential_questions.pdf"
output_path = "./problems/74th/essential_questions_test.xlsx"

question_pdf_converter_to_excel(pdf_path, output_path)
#extract_questions_to_excel(pdf_path, output_path)
# Out:
# デバッグ: ページ 1 の解析開始
# デバッグ: ページ 3 の解析開始
# デバッグ: 問題番号 1 検出
# デバッグ: 問題番号 2 検出
# デバッグ: 問題番号 3 検出
# デバッグ: ページ 4 の解析開始
# デバッグ: 問題番号 4 検出
# デバッグ: 問題番号 5 検出
# デバッグ: 問題番号 6 検出
# デバッグ: ページ 5 の解析開始
# デバッグ: 問題番号 7 検出
# デバッグ: 問題番号 8 検出
# デバッグ: 問題番号 9 検出
# デバッグ: ページ 6 の解析開始
# デバッグ: 問題番号 10 検出
# デバッグ: 問題番号 11 検出
# デバッグ: 問題番号 12 検出
# デバッグ: ページ 7 の解析開始
# デバッグ: 問題番号 13 検出
# デバッグ: 問題番号 14 検出
# デバッグ: 問題番号 15 検出
# デバッグ: ページ 8 の解析開始
# デバッグ: 問題番号 16 検出
# デバッグ: 問題番号 17 検出
# デバッグ: 問題番号 18 検出
# デバッグ: ページ 9 の解析開始
# デバッグ: 問題番号 19 検出
# デバッグ: 問題番号 20 検出
# デバッグ: 問題番号 21 検出
# デバッグ: ページ 10 の解析開始
# デバッグ: 問題番号 22 検出
# デバッグ: 問題番号 23 検出
# デバッグ: 問題番号 24 検出
# デバッグ: ページ 11 の解析開始
# デバッグ: 問題番号 25 検出
# デバッグ: 問題番号 26 検出
# デバッグ: 問題番号 27 検出
# デバッグ: ページ 12 の解析開始
# デバッグ: 問題番号 28 検出
# デバッグ: 問題番号 29 検出
# デバッグ: 問題番号 30 検出
# デバッグ: ページ 13 の解析開始
# デバッグ: 問題番号 31 検出
# デバッグ: 問題番号 32 検出
# デバッグ: 問題番号 33 検出
# デバッグ: ページ 14 の解析開始
# デバッグ: 問題番号 34 検出
# デバッグ: 問題番号 35 検出
# デバッグ: 問題番号 36 検出
# デバッグ: ページ 15 の解析開始
# デバッグ: 問題番号 37 検出
# デバッグ: 問題番号 38 検出
# ...

# %%
# Out:
# 3
