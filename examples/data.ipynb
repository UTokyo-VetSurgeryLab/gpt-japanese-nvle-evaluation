# %%
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result_74th = np.ndarray([
#       2     [
#       3         [
#       4             [
#       5                 [
#       6                     [[47, 46, 45], [46, 45, 43], [44, 47, 42]],
#       7                     [[47, 47, 47], [44, 45, 45], [45, 46, 48]],
#       8                 ],
#       9                 [
#      10                     [[44, 44, 44], [36, 35, 39], [42, 42, 42]],
#      11                     [[43, 43, 44], [44, 44, 43], [43, 42, 43]],
#      12                 ]
#      13             ],
#      14             [
#      15                 [
#      16                     [[80, 78, 79], [77, 77, 75], [77, 77, 76]],
#      17                     [[76, 78, 79], [77, 77, 77], [77, 78, 77]],
#      18                 ],
#      19                 [
# ...
